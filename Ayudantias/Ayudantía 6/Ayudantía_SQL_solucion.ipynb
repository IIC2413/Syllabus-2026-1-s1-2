# %% [markdown]
# En esta guía usted deberá realizar consultas SQL en un servidor virtual con PostgreSQL que contiene
# datos de jugadores de fútbol. El esquema de los datos es el siguiente:
#
# * $\color{green}{\textbf{jugadores}}(
#     \color{blue}{\underline{\text{sofifa_id}}},
#     \color{blue}{\text{nombre}},
#     \color{blue}{\text{nombre_completo}},
#     \color{blue}{\text{precio_eur}},
#     \color{blue}{\text{edad}},
#     \color{blue}{\text{nacimiento}},
#     \color{blue}{\text{altura}},
#     \color{blue}{\text{peso}},
#     \color{blue}{\text{club_id}},
#     \color{blue}{\text{liga_id}},
#     \color{blue}{\text{numero}},
#     \color{blue}{\text{fecha_ingreso}},
#     \color{blue}{\text{nacionalidad_id}},
#     \color{blue}{\text{pie}}
# )$
# * $\color{green}{\textbf{ligas}}(
#     \color{blue}{\underline{\text{liga_id}}},
#     \color{blue}{\text{nombre}}
# )$
# * $\color{green}{\textbf{clubes}}(
#     \color{blue}{\underline{\text{club_id}}},
#     \color{blue}{\text{nombre}},
#     \color{blue}{\text{liga_id}}
# )$
# * $\color{green}{\textbf{nacionalidades}}(
#     \color{blue}{\underline{\text{nacionalidad_id}}},
#     \color{blue}{\text{nombre}}
# )$
# * $\color{green}{\textbf{posiciones}}(
#     \color{blue}{\underline{\text{posicion_id}}},
#     \color{blue}{\text{nombre}}
# )$
#
# * $\color{green}{\textbf{jugador_posiciones}}(
#     \color{blue}{\underline{\text{jugador_id}}},
#     \color{blue}{\underline{\text{posicion_id}}}
# )$
#
# Para iniciar el servidor virtual, instalar la base de datos postgres, y descargar los datos e importarlos, debe correr el siguiente bloque:

# %%
# install
# !apt update -qq
# !apt install postgresql postgresql-contrib -y -qq
# !service postgresql start
# !sudo -u postgres psql -c "CREATE USER root WITH SUPERUSER PASSWORD 'root';"
# !sudo -u postgres createdb guia -O root
# set connection
# !wget -O /content/players_22.csv "https://drive.google.com/uc?export=download&id=1xXrtS05885IRuV7rVQLjtEnbvQLdqcyW"
# !wget -O /content/poblar_tablas.sql "https://drive.google.com/uc?export=download&id=1-yWZBISuRbOnyCb0AWeUD_UR325FlcYU"
# %load_ext sql
# %config SqlMagic.feedback=False
# %config SqlMagic.autopandas=True
# %sql postgresql+psycopg2://root:root@localhost/guia
# !psql -U root -d guia -f /content/poblar_tablas.sql
# Out:
# 41 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# postgresql is already the newest version (14+238).
# postgresql-contrib is already the newest version (14+238).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
#  * Starting PostgreSQL 14 database server
#    ...done.
# ERROR:  role "root" already exists
# createdb: error: database creation failed: ERROR:  database "guia" already exists
# --2025-09-24 17:31:15--  https://drive.google.com/uc?export=download&id=1xXrtS05885IRuV7rVQLjtEnbvQLdqcyW
# Resolving drive.google.com (drive.google.com)... 172.217.12.14, 2607:f8b0:4025:803::200e
# Connecting to drive.google.com (drive.google.com)|172.217.12.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1xXrtS05885IRuV7rVQLjtEnbvQLdqcyW&export=download [following]
# --2025-09-24 17:31:16--  https://drive.usercontent.google.com/download?id=1xXrtS05885IRuV7rVQLjtEnbvQLdqcyW&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.164.1, 2607:f8b0:4025:803::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.164.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2720372 (2.6M) [application/octet-stream]
# Saving to: ‘/content/players_22.csv’
#
# /content/players_22 100%[===================>]   2.59M  --.-KB/s    in 0.1s
#
# 2025-09-24 17:31:17 (21.5 MB/s) - ‘/content/players_22.csv’ saved [2720372/2720372]
#
# --2025-09-24 17:31:17--  https://drive.google.com/uc?export=download&id=1-yWZBISuRbOnyCb0AWeUD_UR325FlcYU
# Resolving drive.google.com (drive.google.com)... 172.217.12.14, 2607:f8b0:4025:803::200e
# Connecting to drive.google.com (drive.google.com)|172.217.12.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1-yWZBISuRbOnyCb0AWeUD_UR325FlcYU&export=download [following]
# --2025-09-24 17:31:17--  https://drive.usercontent.google.com/download?id=1-yWZBISuRbOnyCb0AWeUD_UR325FlcYU&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.164.1, 2607:f8b0:4025:803::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.164.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1459 (1.4K) [application/octet-stream]
# Saving to: ‘/content/poblar_tablas.sql’
#
# /content/poblar_tab 100%[===================>]   1.42K  --.-KB/s    in 0s
#
# 2025-09-24 17:31:19 (17.6 MB/s) - ‘/content/poblar_tablas.sql’ saved [1459/1459]
#
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# CREATE TABLE
# COPY 19239
# psql:/content/poblar_tablas.sql:24: NOTICE:  drop cascades to constraint jugador_posiciones_jugador_id_fkey on table jugador_posiciones
# DROP TABLE
# CREATE TABLE
# INSERT 0 19239

# %% [markdown]
# Ejecute la siguiente consulta para probar que todo ande bien:

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %sql SELECT * FROM datos LIMIT 5;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    sofifa_id             nombre                      nombre_completo  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1     188545     R. Lewandowski                   Robert Lewandowski
# 2      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#    posiciones   precio_eur  edad  nacimiento  altura  peso  \
# 0  RW, ST, CF   78000000.0    34  1987-06-24     170    72
# 1          ST  119500000.0    32  1988-08-21     185    81
# 2      ST, LW   45000000.0    36  1985-02-05     187    83
# 3     LW, CAM  129000000.0    29  1992-02-05     175    68
# 4     CM, CAM  125500000.0    30  1991-06-28     181    70
#
#                   club                    liga  numero fecha_ingreso  \
# 0  Paris Saint-Germain          French Ligue 1      30    2021-08-10
# 1    FC Bayern München    German 1. Bundesliga       9    2014-07-01
# 2    Manchester United  English Premier League       7    2021-08-27
# 3  Paris Saint-Germain          French Ligue 1      10    2017-08-03
# 4      Manchester City  English Premier League      17    2015-08-30
#
#   nacionalidad    pie
# 0    Argentina   Left
# 1       Poland  Right
# 2     Portugal  Right
# 3       Brazil  Right
# 4      Belgium  Right

# %% [markdown]
# Para ejecutar consultas multi-lineas use el tag %%sql:

# %%
# %%sql
# SELECT *
# FROM datos
# where nombre ilike '%Messi%';
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    sofifa_id          nombre                 nombre_completo   posiciones  \
# 0     158023        L. Messi  Lionel Andrés Messi Cuccittini   RW, ST, CF
# 1     240938  Junior Messias           Junior Walter Messias  CAM, CF, CM
#
#    precio_eur  edad  nacimiento  altura  peso                 club  \
# 0  78000000.0    34  1987-06-24     170    72  Paris Saint-Germain
# 1   4100000.0    30  1991-05-13     179    70             AC Milan
#
#               liga  numero fecha_ingreso nacionalidad   pie
# 0   French Ligue 1      30    2021-08-10    Argentina  Left
# 1  Italian Serie A      30          None       Brazil  Left

# %% [markdown]
# # SQL - Modificaciones

# %% [markdown]
# Crear tabla ligas con liga_id(PK) y nombre.

# %%
# %%sql
# DROP TABLE IF EXISTS ligas CASCADE;
# CREATE TABLE ligas (
#     liga_id SERIAL PRIMARY KEY,
#     nombre VARCHAR(100) UNIQUE NOT NULL
# );
#
# -- llenar tabla ligas
# INSERT INTO ligas (nombre)
# SELECT DISTINCT liga
# FROM datos
# WHERE liga IS NOT NULL;
#
# SELECT *
# FROM ligas
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    liga_id                         nombre
# 0        1              Turkish Süper Lig
# 1        2             Ecuadorian Serie A
# 2        3  Japanese J. League Division 1
# 3        4    Chilian Campeonato Nacional
# 4        5        English National League

# %% [markdown]
# Crear tabla clubes con club_id(PK), nombre y liga_id(FK).

# %%
# %%sql
# DROP TABLE IF EXISTS clubes CASCADE;
# CREATE TABLE clubes (
#     club_id SERIAL PRIMARY KEY,
#     nombre VARCHAR(100) UNIQUE NOT NULL,
#     liga_id INT REFERENCES ligas(liga_id)
# );
#
# -- llenar tabla clubes
# INSERT INTO clubes (nombre, liga_id)
# SELECT DISTINCT d.club, l.liga_id
# FROM datos d
# JOIN ligas l ON d.liga = l.nombre
# WHERE d.club IS NOT NULL;
#
# SELECT *
# FROM clubes
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    club_id                   nombre  liga_id
# 0        1         Panathinaikos FC       16
# 1        2  Independiente del Valle        2
# 2        3                   Al Tai       41
# 3        4   St. Patrick's Athletic       33
# 4        5                Morecambe       26

# %% [markdown]
# Crear tabla nacionalidades con nacionalidad_id (PK) y nombre.

# %%
# %%sql
# DROP TABLE IF EXISTS nacionalidades CASCADE;
# CREATE TABLE nacionalidades (
#     nacionalidad_id SERIAL PRIMARY KEY,
#     nombre VARCHAR(100) UNIQUE NOT NULL
# );
#
# -- llenar tabla nacionalidades
# INSERT INTO nacionalidades (nombre)
# SELECT DISTINCT nacionalidad
# FROM datos
# WHERE nacionalidad IS NOT NULL;
#
# SELECT *
# FROM nacionalidades
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    nacionalidad_id          nombre
# 0                1       Indonesia
# 1                2       Venezuela
# 2                3        Cameroon
# 3                4      Luxembourg
# 4                5  Czech Republic

# %% [markdown]
# Crear la tabla jugadores.

# %%
# %%sql
# DROP TABLE IF EXISTS jugadores CASCADE;
# CREATE TABLE jugadores (
#     sofifa_id INTEGER PRIMARY KEY,
#     nombre TEXT,
#     nombre_completo TEXT,
#     precio_eur NUMERIC,
#     edad INTEGER,
#     nacimiento DATE,
#     altura INTEGER,
#     peso INTEGER,
#     club_id INT REFERENCES clubes(club_id),
#     liga_id INT REFERENCES ligas(liga_id),
#     numero INTEGER,
#     fecha_ingreso DATE,
#     nacionalidad_id INT REFERENCES nacionalidades(nacionalidad_id),
#     pie TEXT
# );
#
#
# INSERT INTO jugadores (sofifa_id, nombre, nombre_completo, precio_eur, edad, nacimiento, altura, peso, club_id, liga_id, numero, fecha_ingreso, nacionalidad_id, pie)
# SELECT d.sofifa_id,
#        d.nombre,
#        d.nombre_completo,
#        d.precio_eur,
#        d.edad,
#        d.nacimiento,
#        d.altura,
#        d.peso,
#        c.club_id,
#        l.liga_id,
#        d.numero,
#        d.fecha_ingreso,
#        n.nacionalidad_id,
#        d.pie
# FROM datos d
# LEFT JOIN clubes c ON d.club = c.nombre
# LEFT JOIN ligas l ON d.liga = l.nombre
# LEFT JOIN nacionalidades n ON d.nacionalidad = n.nombre;
#
# SELECT *
# FROM jugadores
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    sofifa_id             nombre                      nombre_completo  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1     188545     R. Lewandowski                   Robert Lewandowski
# 2      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#     precio_eur  edad  nacimiento  altura  peso  club_id  liga_id  numero  \
# 0   78000000.0    34  1987-06-24     170    72      646       17      30
# 1  119500000.0    32  1988-08-21     185    81       93       53       9
# 2   45000000.0    36  1985-02-05     187    83      103       10       7
# 3  129000000.0    29  1992-02-05     175    68      646       17      10
# 4  125500000.0    30  1991-06-28     181    70      329       10      17
#
#   fecha_ingreso  nacionalidad_id    pie
# 0    2021-08-10               91   Left
# 1    2014-07-01              156  Right
# 2    2021-08-27               15  Right
# 3    2017-08-03              133  Right
# 4    2015-08-30               72  Right

# %% [markdown]
# Crear tabla posiciones.

# %%
# %%sql
# DROP TABLE IF EXISTS posiciones CASCADE;
# CREATE TABLE posiciones (
#     posicion_id SERIAL PRIMARY KEY,
#     nombre VARCHAR(10) UNIQUE NOT NULL
# );
#
# -- llenar posiciones
# INSERT INTO posiciones (nombre)
# SELECT DISTINCT unnest(string_to_array(posiciones, ', ')) AS pos
# FROM datos
# WHERE posiciones IS NOT NULL;
#
# SELECT *
# FROM posiciones
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    posicion_id nombre
# 0            1     CB
# 1            2     LB
# 2            3     RW
# 3            4     RB
# 4            5    CAM

# %% [markdown]
# Relacionar jugadores y posiciones.

# %%
# %%sql
# DROP TABLE IF EXISTS jugador_posiciones CASCADE;
# CREATE TABLE jugador_posiciones (
#     jugador_id INT,
#     posicion_id INT,
#     PRIMARY KEY (jugador_id, posicion_id),
#     FOREIGN KEY (jugador_id) REFERENCES jugadores(sofifa_id),
#     FOREIGN KEY (posicion_id) REFERENCES posiciones(posicion_id)
# );
#
# INSERT INTO jugador_posiciones (jugador_id, posicion_id)
# SELECT j.sofifa_id, p.posicion_id
# FROM datos d
# JOIN jugadores j ON d.sofifa_id = j.sofifa_id
# JOIN posiciones p ON p.nombre = ANY(string_to_array(d.posiciones, ', '))
# WHERE d.posiciones IS NOT NULL;
#
# SELECT *
# FROM jugador_posiciones
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#    jugador_id  posicion_id
# 0      158023           10
# 1      158023            3
# 2      158023           11
# 3      188545           11
# 4       20801            7

# %% [markdown]
# Ahora, debe diseñar las consultas que resuelvan las siguientes preguntas usando los operadores vistos en clases.
#
# #SQL - Consultas
# ## Pregunta 1
# 1a. TOP 10 JUGADORES MAS CAROS: muestra en orden descendiente los jugadores en los cuales su precio sea mayor.

# %%
# %%sql
# SELECT j.nombre AS jugador,
#        j.precio_eur AS valor_total_jugadores
# FROM jugadores j
# WHERE precio_eur > 0
# ORDER BY j.precio_eur DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#                jugador valor_total_jugadores
# 0            K. Mbappé           194000000.0
# 1           E. Haaland           137500000.0
# 2              H. Kane           129500000.0
# 3            Neymar Jr           129000000.0
# 4         K. De Bruyne           125500000.0
# 5        G. Donnarumma           119500000.0
# 6           F. de Jong           119500000.0
# 7       R. Lewandowski           119500000.0
# 8            J. Sancho           116500000.0
# 9  T. Alexander-Arnold           114000000.0

# %% [markdown]
# 1b. TOP 10 CLUBES MAS CAROS: muestra en orden descendiente los clubes en los cuales la sumatoria de los precios de sus jugadores sea mayor.

# %%
# %%sql
# SELECT c.nombre AS club,
#        SUM(j.precio_eur) AS valor_total_jugadores
# FROM jugadores j
# JOIN clubes c
#   ON j.club_id = c.club_id
# GROUP BY c.nombre
# ORDER BY valor_total_jugadores DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#                   club valor_total_jugadores
# 0      Manchester City          1299510000.0
# 1  Paris Saint-Germain          1227400000.0
# 2            Liverpool          1046375000.0
# 3    Manchester United          1008730000.0
# 4       Real Madrid CF           987575000.0
# 5    FC Bayern München           969475000.0
# 6   Atlético de Madrid           952475000.0
# 7              Chelsea           934150000.0
# 8         FC Barcelona           834300000.0
# 9             Juventus           774900000.0

# %% [markdown]
# ## Pregunta 2
# 2. TOP 10 DIAS QUE MAS GANACIA A GENERADO: muestra en orden descendiente los dias en los cuales la suma total de los precios de los jugadores nacidos ese dia sea mayor.

# %%
# %%sql
# SELECT nacimiento AS mes_nacimiento,
#        COUNT(*) AS cantidad_jugadores,
#        SUM(precio_eur) AS valor_total_jugadores
# FROM jugadores
# WHERE precio_eur > 0
# GROUP BY mes_nacimiento
# ORDER BY valor_total_jugadores DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#   mes_nacimiento  cantidad_jugadores valor_total_jugadores
# 0     2000-02-29                  92           496325000.0
# 1     1992-02-29                 125           474685000.0
# 2     1996-02-29                 120           417050000.0
# 3     1998-12-20                   4           199425000.0
# 4     1994-05-27                   5           176640000.0
# 5     1992-02-05                   3           174400000.0
# 6     1999-02-25                  11           148005000.0
# 7     2000-03-25                   9           145000000.0
# 8     1996-06-22                   8           139500000.0
# 9     2000-07-21                   2           138300000.0

# %% [markdown]
# # Pregunta 3
# 3. TOP 25 JUGADORES QUE JUEGAN MAS DE UNA POSICION: muestra en orden descendiente los 25 mejores jugadores (segun precio de mercado) que jueguen mas de una posicion, en caso de empate compara por edad ascendente.

# %%
# %%sql
# SELECT j.nombre AS nombre_jugador,
#        c.nombre AS club,
#        l.nombre AS liga,
#        j.edad,
#        j.precio_eur,
#        COUNT(p.posicion_id) AS cantidad_posiciones
# FROM jugadores j
# JOIN clubes c
#   ON j.club_id = c.club_id
# JOIN ligas l
#   ON c.liga_id = l.liga_id
# JOIN jugador_posiciones jp
#   ON j.sofifa_id = jp.jugador_id
# JOIN posiciones p
#   ON jp.posicion_id = p.posicion_id
# WHERE precio_eur > 0
# GROUP BY j.sofifa_id, j.nombre, c.nombre, l.nombre, j.edad, j.precio_eur
# HAVING COUNT(p.posicion_id) > 1
# ORDER BY j.precio_eur DESC,
#          j.edad ASC
# LIMIT 25;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#      nombre_jugador                 club                    liga  edad  \
# 0         K. Mbappé  Paris Saint-Germain          French Ligue 1    22
# 1         Neymar Jr  Paris Saint-Germain          French Ligue 1    29
# 2      K. De Bruyne      Manchester City  English Premier League    30
# 3        F. de Jong         FC Barcelona  Spain Primera Division    24
# 4         J. Sancho    Manchester United  English Premier League    21
# 5        J. Kimmich    FC Bayern München    German 1. Bundesliga    26
# 6       R. Sterling      Manchester City  English Premier League    26
# 7            H. Son    Tottenham Hotspur  English Premier League    28
# 8          N. Kanté              Chelsea  English Premier League    30
# 9          P. Foden      Manchester City  English Premier League    21
# 10       K. Havertz              Chelsea  English Premier League    22
# 11      L. Goretzka    FC Bayern München    German 1. Bundesliga    26
# 12        P. Dybala             Juventus         Italian Serie A    27
# 13       Marquinhos  Paris Saint-Germain          French Ligue 1    27
# 14  Marcos Llorente   Atlético de Madrid  Spain Primera Division    26
# 15       João Félix   Atlético de Madrid  Spain Primera Division    21
# 16         K. Coman    FC Bayern München    German 1. Bundesliga    25
# 17        F. Chiesa             Juventus         Italian Serie A    23
# 18   Bernardo Silva      Manchester City  English Premier League    26
# 19         P. Pogba    Manchester United  English Premier League    28
# 20      M. Verratti  Paris Saint-Germain          French Ligue 1    28
# 21         L. Messi  Paris Saint-Germain          French Ligue 1    34
# 22      M. Rashford    Manchester United  English Premier League    23
# 23        Oyarzabal        Real Sociedad  Spain Primera Division    24
# 24          Fabinho            Liverpool  English Premier League    27
#
#      precio_eur  cantidad_posiciones
# 0   194000000.0                    2
# 1   129000000.0                    2
# 2   125500000.0                    2
# 3   119500000.0                    3
# 4   116500000.0                    3
# 5   108000000.0                    2
# 6   107500000.0                    2
# 7   104000000.0                    3
# 8   100000000.0                    2
# 9    94500000.0                    3
# 10   94500000.0                    3
# 11   93000000.0                    2
# 12   93000000.0                    2
# 13   90500000.0                    2
# 14   88000000.0                    3
# 15   82000000.0                    2
# 16   81000000.0                    3
# 17   80500000.0                    3
# 18   80000000.0                    3
# 19   79500000.0                    2
# 20   79500000.0                    2
# 21   78000000.0                    3
# 22   77500000.0                    2
# 23   77500000.0                    2
# 24   73500000.0                    2

# %% [markdown]
# ## Pregunta 4
# 4. TOP 12 MESES CON MAS JUGADORES: muestra en orden descendiente los meses en los cuales mas jugadores han nacido.

# %%
# %%sql
# WITH datos AS (
#     SELECT TO_CHAR(j.fecha_ingreso, 'MM-YYYY') AS mes,
#            j.sofifa_id,
#            j.precio_eur
#     FROM jugadores j
#     WHERE j.fecha_ingreso IS NOT NULL
# )
# SELECT mes,
#        COUNT(*) AS cantidad_jugadores,
#        SUM(precio_eur) AS valor_total_jugadores
# FROM datos
# GROUP BY mes
# ORDER BY cantidad_jugadores DESC
# LIMIT 12;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#         mes  cantidad_jugadores valor_total_jugadores
# 0   07-2021                2843          6180915000.0
# 1   07-2019                1396          5297040000.0
# 2   01-2021                1144          1328505000.0
# 3   08-2021                1016          2864045000.0
# 4   01-2020                 931          2034160000.0
# 5   08-2020                 916          2138115000.0
# 6   07-2020                 848          1563245000.0
# 7   07-2018                 775          3609950000.0
# 8   09-2020                 636          2320220000.0
# 9   01-2019                 562          1180845000.0
# 10  07-2017                 476          2626505000.0
# 11  02-2021                 471           610920000.0

# %% [markdown]
# ## Pregunta 5
# 5. EQUIPOS CON MAS JUGADORES NACIDOS EL MISMO MES: muestra el top 10 de equipos donde mas jugadores esten de cumpleaños el mismo mes.

# %%
# %%sql
# SELECT c.nombre AS club,
#        TO_CHAR(j.nacimiento, 'MM') AS mes_nacimiento,
#        COUNT(*) AS cantidad_jugadores
# FROM jugadores j
# JOIN clubes c
#   ON j.club_id = c.club_id
# WHERE j.nacimiento IS NOT NULL
# GROUP BY c.nombre, mes_nacimiento
# ORDER BY cantidad_jugadores DESC;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#                            club mes_nacimiento  cantidad_jugadores
# 0                     Palmeiras             02                  20
# 1     Atlético Clube Goianiense             02                  20
# 2                 RB Bragantino             02                  20
# 3        Clube Atlético Mineiro             02                  20
# 4                         Bahia             02                  20
# ...                         ...            ...                 ...
# 7345               MSV Duisburg             09                   1
# 7346      Club de Foot Montréal             12                   1
# 7347          Preston North End             08                   1
# 7348                  Brentford             10                   1
# 7349             Stabæk Fotball             02                   1
#
# [7350 rows x 3 columns]

# %% [markdown]
# ## Pregunta 6
# 6. CLUBES CON MAYOR VALOR Y EDAD PROMEDIO: muestra el top 10 de equipos con mercado y edad mas altos.

# %%
# %%sql
# SELECT c.nombre AS club,
#        l.nombre AS liga,
#        SUM(j.precio_eur) AS valor_total_jugadores,
#        AVG(j.edad)::numeric(4,2) AS edad_promedio
# FROM jugadores j
# JOIN clubes c ON j.club_id = c.club_id
# JOIN ligas l ON c.liga_id = l.liga_id
# GROUP BY c.nombre, l.nombre
# ORDER BY valor_total_jugadores DESC, edad_promedio DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg2://root:***@localhost/guia
#                   club                    liga valor_total_jugadores  \
# 0      Manchester City  English Premier League          1299510000.0
# 1  Paris Saint-Germain          French Ligue 1          1227400000.0
# 2            Liverpool  English Premier League          1046375000.0
# 3    Manchester United  English Premier League          1008730000.0
# 4       Real Madrid CF  Spain Primera Division           987575000.0
# 5    FC Bayern München    German 1. Bundesliga           969475000.0
# 6   Atlético de Madrid  Spain Primera Division           952475000.0
# 7              Chelsea  English Premier League           934150000.0
# 8         FC Barcelona  Spain Primera Division           834300000.0
# 9             Juventus         Italian Serie A           774900000.0
#
#   edad_promedio
# 0         24.31
# 1         25.94
# 2         25.00
# 3         25.85
# 4         25.00
# 5         24.79
# 6         25.25
# 7         24.82
# 8         24.15
# 9         26.31
